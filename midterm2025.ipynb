# %% [markdown]
# <a href="https://colab.research.google.com/github/woraphonp-038-5/dataviz2025/blob/main/midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# # หาคดีฆาตรกรรมที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City

# %%
crime_scene_report_df = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/crime_scene_report.csv')
crime_scene_report_df.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#           city
# 0          NYC
# 1       Albany
# 2         Reno
# 3  Pandas City
# 4  Pandas City

# %%
#
murder_crimes_df = crime_scene_report_df[
    (crime_scene_report_df['date'] == 20180115) &
    (crime_scene_report_df['type'] == 'murder')&
    (crime_scene_report_df['city'] == 'Pandas City')
    ]
murder_crimes_df.head()
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 1227  Pandas City

# %% [markdown]
# # หาพยาน 2 คน

# %%
person_df = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/person.csv')
person_df.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
# พยานคนที่ 1 จากเมือง Northwestern Dr
person_df1 = person_df[(person_df['address_street_name'] == 'Northwestern Dr')]
person_df1.head()
# Out:
#         id            name  license_id  address_number address_street_name  \
# 2    10010       Muoi Cary      385336             741     Northwestern Dr
# 282  12711  Norman Apolito      667757             599     Northwestern Dr
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 528  15171    Weldon Penso      336999             311     Northwestern Dr
# 811  17729  Lasonya Wildey      439686            3824     Northwestern Dr
#
#            ssn
# 2    828638512
# 282  778264744
# 499  111564949
# 528  131379495
# 811  917817122

# %%
# พยานคนที่ 1
# Sort by address number in descending order to find the last house
first_witness_df = person_df1.sort_values(by='address_number', ascending=False)
first_witness_df.head(1)
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %%
# พยานคนที่ 2
person_df2 = person_df[(person_df['address_street_name'] == 'Franklin Ave')]
person_df2.head()
# Out:
#          id            name  license_id  address_number address_street_name  \
# 235   12207  Wilmer Wolever      509484             139        Franklin Ave
# 665   16371  Annabel Miller      490173             103        Franklin Ave
# 807   17683   Johnnie Schee      968887            1277        Franklin Ave
# 936   18651   Carleen Etoll      356746              22        Franklin Ave
# 1377  22636  Zachary Ybarbo      768359             785        Franklin Ave
#
#             ssn
# 235   636825374
# 665   318771143
# 807   815977821
# 936   193369255
# 1377  285346605

# %%
# พยานคนที่ 2 คือ Annabel Miller

# %% [markdown]
# # หา interview ของพยานทั้งสองคน

# %%
interview = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/interview.csv')
interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
# หา interview
interview = interview[
    (interview['person_id'] == 16371) | (interview['person_id'] == 14887)]
interview
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# # หาคนร้าย

# %%
get_fit_now_check_in = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/get_fit_now_check_in.csv')
get_fit_now_check_in.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
# หาคนร้านที่เช็คอินยิมจากเบาะแส January the 9th.
find_get_fit_now_check_in = get_fit_now_check_in[
    (get_fit_now_check_in['membership_id'] == '48Z55') |
    (get_fit_now_check_in['membership_id'] == '48Z7A')
]
find_get_fit_now_check_in
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700

# %%
get_fit_now_member = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/get_fit_now_member.csv')
get_fit_now_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
# หาคนร้ายที่จากเบาะแส The membership number on the bag started with "48Z"
find_get_fit_now_member = get_fit_now_member[
    (get_fit_now_member['membership_status'] == 'gold') &
    (get_fit_now_member['id'].str.startswith('48Z'))
]
find_get_fit_now_member.head()
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
person_df = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/person.csv')
person_df.head()
# ใช้ชื่อเพื่อหา drivers_license
find_person_df = person_df[
    (person_df['name'] == 'Joe Germuska')|
    (person_df['name'] == 'Jeremy Bowers')]
find_person_df
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 2037  28819   Joe Germuska      173289             111                Fisk Rd
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 2037  138909730
# 6327  871539279

# %%
drivers_license = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/drivers_license.csv')
drivers_license.head()
# ใช้ชื่อเพื่อหา plate_number จากเบาะแส The man got into a car with a plate that included "H42W".
find_drivers_license = drivers_license[
    (drivers_license['id'] == 173289)| #Joe Germuska
     (drivers_license['id'] == 423327) #Jeremy Bowers <- คนร้าย
     ]
find_drivers_license
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#      car_model
# 3529  Spark LS

# %%
interview = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/interview.csv')
interview.head()
# หา interview ฆาตรกร
interview = interview[
    (interview['person_id'] == 67318)]
interview
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# # หาคนบงการ

# %%
drivers_license = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/drivers_license.csv')
drivers_license.head()
# หาคนบงการจากเบาะแส I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S
find_drivers_license = drivers_license[
    (drivers_license['car_make'] == 'Tesla')&
    (drivers_license['car_model'] == 'Model S')&
    (drivers_license['hair_color'] == 'red')&
    (drivers_license['gender'] == 'female')
     ]
find_drivers_license
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %%
person_df = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/person.csv')
person_df.head()
# ใช้ drivers_license เพื่อหาชื่อคนบงการ
find_person_df = person_df[
    (person_df['license_id'] == 202298)|
    (person_df['license_id'] == 291182)|
    (person_df['license_id'] == 918773)
    ]
find_person_df
# Out:
#          id              name  license_id  address_number address_street_name  \
# 7664  78881          Red Korb      918773             107         Camerata Dr
# 8977  90700     Regina George      291182             332           Maple Ave
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 7664  961388910
# 8977  337169072
# 9985  987756388

# %%
# ใช้ person_id เพื่อหาชื่อคนบงการจากเบาะแส I know that she attended the SQL Symphony Concert 3 times in December 2017.
facebook_event_checkin = pd.read_csv('/content/drive/MyDrive/Exam Data DataViz2025/facebook_event_checkin.csv')
find_facebook_event_checkin = facebook_event_checkin[
    (facebook_event_checkin['person_id'] == 78881)|
    (facebook_event_checkin['person_id'] == 90700)|
    (facebook_event_checkin['person_id'] == 99716)
    ]

find_facebook_event_checkin
# Out:
#        person_id  event_id            event_name      date
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229

# %% [markdown]
# # สรุป
#
# คนร้ายคือ Jeremy Bowers
#
# คนบงการคือ Miranda Priestly

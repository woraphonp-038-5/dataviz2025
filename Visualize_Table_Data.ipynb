# %% [markdown]
# <a href="https://colab.research.google.com/github/woraphonp-038-5/dataviz2025/blob/main/Visualize_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Loutcomes1 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-city-of-london-outcomes.csv')
Loutcomes2 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-02/2025-02-city-of-london-outcomes.csv')
Loutcomes3 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-03/2025-03-city-of-london-outcomes.csv')

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
display(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris_df = iris_df.drop('target', axis=1)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # Heatmap

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %%
matplotlib.rcParams['figure.figsize'] = (5, 5) #กำหนดขนาด figure

plt.imshow(iris_df.iloc[:,:],interpolation = 'nearest')

# %%
matplotlib.rcParams['figure.figsize'] = (15, 45) #กำหนดขนาด figure

plt.imshow(iris_df.iloc[:,:],interpolation = 'nearest')

# %% [markdown]
# # pandas: parallel coordinate

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
display(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
matplotlib.rcParams['figure.figsize'] = (5, 5) #กำหนดขนาด figure
pd.plotting.parallel_coordinates(iris_df, 'target')
# Out:
# <Axes: >

# %% [markdown]
# # pandas: scatter matrix

# %%
pd.plotting.scatter_matrix(iris_df);

# %% [markdown]
# #**Color**

# %% [markdown]
# color map

# %%
matplotlib.rcParams['figure.figsize'] = (15, 45) #กำหนดขนาด figure
plt.imshow(iris_df.iloc[:,:],interpolation = 'nearest',cmap='rainbow')

# %% [markdown]
# color - code

# %%
matplotlib.rcParams['figure.figsize']=[5,5]
pd.plotting.parallel_coordinates(iris_df, 'target',color=['c','m','y']); #ตัวย่อชื่อสี c m y k r g b w

# %%
matplotlib.rcParams['figure.figsize']=[5,5]
pd.plotting.parallel_coordinates(iris_df, 'target',color=[[1,0,0],[0.5,0.5,0.5],[0,1,1]]); #ค่าสี R G B

# %%
matplotlib.rcParams['figure.figsize']=[5,5]
pd.plotting.parallel_coordinates(iris_df, 'target',color=['#375878','#783760','#D4C600']); #html color code

# %% [markdown]
# <a href="https://colab.research.google.com/github/woraphonp-038-5/dataviz2025/blob/main/Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
bfs_outcome_df = pd.read_csv('/content/2025-01-bedfordshire-outcomes.csv')

# %%
bfs_outcome_df.head(5)

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_stopandsearch = '/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %% [markdown]
# ## load data to memory

# %%
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
path_to_stopandsearch = '/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.tail()
# Out:
#                           Type                       Date  \
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 385                         False                 NaN  51.878459  -0.422384
# 386                         False                 NaN  51.878459  -0.422384
#
#      Gender Age range                             Self-defined ethnicity  \
# 382  Female   over 34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
stopandsearch_df['Outcome'][200]

# %% [markdown]
# ### list ซ้อน list ซ้อน list ซ้อน Dict ซ้อน list

# %%
ex_list = [[[1,2,3],['a','b','c']],
            [['x','y','z'],['ab',1,2]],
            [{'a':1,'b':2},{'XX':5,'YY':6}]]

# %%
ex_list[2][1]['XX']

# %%
stopandsearch_df['Outcome'][383][384]

# %%
stopandsearch_df['Object of search'][384:386]

# %% [markdown]
# #### .iloc

# %%
stopandsearch_df.iloc[200,12]

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
stopandsearch_df.info()

# %%
smaller_table = stopandsearch_df[['Outcome','Age range',
                                  'Longitude','Latitude',
                                  'Self-defined ethnicity']][:5]
smaller_table

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
stopandsearch_df.iloc[1:5,:-10]

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query(conditional statement))

# %% [markdown]
# #### อยากได้ row ที่เป็น policing operation

# %%
stopandsearch_df['Part of a policing operation']== True

# %%
stopandsearch_df[stopandsearch_df['Part of a policing operation'] == True]

# %% [markdown]
# ## ตัวอย่าง Table Query ง่ายๆ

# %%
smaller_table

# %%
smaller_table[[True,False,True,False,False]]

# %% [markdown]
# # quiz 8 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (387-25)*[False]

# %%
stopandsearch_df[list_log1+list_logM+list_log2]

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are True, the rest are False.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (226-25)*[False]

# %%
list_log1 = [True] * 10
list_log2 = [False] * (stopandsearch_df.shape[0] - 25)
list_log3 = [True] * 15
stopandsearch_df[list_log1 + list_log2 + list_log3]

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# # quiz 8-2
#
# 1. อยากรู้ว่า ในเดือนกุมภาพันธ์ ปี 2025 ผู้ที่ถูกเรียกค้นที่เป็นคน white-English,... เมือง city of London หรือ เมือง Cambridgeshire มีเยอะกว่ากัน และ เยอะกว่าเท่าไหร่

# %%
# Load the City of London data
path_to_london_data = '/content/drive/MyDrive/Python&DataViz2025/data/2025-02/2025-02-city-of-london-stop-and-search.csv'
london_df = pd.read_csv(path_to_london_data)
london_df.head()

# %%
# Load the Cambridgeshire data
path_to_cambridge_data = '/content/drive/MyDrive/Python&DataViz2025/data/2025-02/2025-02-cambridgeshire-stop-and-search.csv'
cambridge_df = pd.read_csv(path_to_cambridge_data)
cambridge_df.head()

# %%
# Filter for 'White - English/Welsh/Scottish/Northern Irish/British' in both dataframes
london_white_english = london_df[london_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']
cambridge_white_english = cambridge_df[cambridge_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']

# Get the counts
london_count = len(london_white_english)
cambridge_count = len(cambridge_white_english)

# Print the results
print(f"Number of 'White - English/...' stop and searches in City of London: {london_count}")
print(f"Number of 'White - English/...' stop and searches in Cambridgeshire: {cambridge_count}")

# Compare and print the difference
if london_count > cambridge_count:
    print(f"City of London had {london_count - cambridge_count} more stop and searches of 'White - English/...' people than Cambridgeshire.")
elif cambridge_count > london_count:
    print(f"Cambridgeshire had {cambridge_count - london_count} more stop and searches of 'White - English/...' people than City of London.")
else:
    print("Both cities had the same number of stop and searches of 'White - English/...' people.")

# %% [markdown]
# #HW 4 (group) ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
os.listdir('/content/drive/MyDrive/Python&DataViz2025/data/2025-02')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import pandas as pd

def read_all_data(base_path):
    all_data = []

    for month in os.listdir(base_path):
        month_path = os.path.join(base_path, month)
        if not os.path.isdir(month_path):
            continue

        for file in os.listdir(month_path):
            if 'stop-and-search' not in file:
                continue

            file_path = os.path.join(month_path, file)

            try:
                df = pd.read_csv(file_path)

                # แยกชื่อเมืองจากชื่อไฟล์ เช่น avon-and-somerset
                city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1].strip()
                df['เมือง'] = city
                all_data.append(df)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

    return pd.concat(all_data, ignore_index=True)

# %%
# 1. อ่านข้อมูลทั้งหมด
base_path = "/content/drive/MyDrive/Python&DataViz2025/data"
df_all = read_all_data(base_path)

# 2. กรองเฉพาะคนที่ระบุว่าเป็นคน Asia
# ใช้ self-defined-ethnicity ถ้ามี
eth_col = "Self-defined ethnicity" if "Self-defined ethnicity" in df_all.columns else "ethnicity"

df_asian = df_all[df_all[eth_col].str.contains("Asian", case=False, na=False)]

# 3. Group by เมืองแล้วนับจำนวน
summary = df_asian.groupby("เมือง").size().reset_index(name="Asian Count")

# 4. หาค่าน้อยสุดและมากสุด
min_row = summary.loc[summary["Asian Count"].idxmin()]
max_row = summary.loc[summary["Asian Count"].idxmax()]

print("เมืองที่มีคนเอเชียน้อยที่สุด:")
print(min_row)

print("\nเมืองที่มีคนเอเชียมากที่สุด:")
print(max_row)

# %% [markdown]
# #HW 5 (เดี่ยว) ***แก้จาก code เดิม*** ยอดรวมทุกเมือง เดือนไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

def read_all_data(base_path):
    all_data = []

    for month in os.listdir(base_path):
        month_path = os.path.join(base_path, month)
        if not os.path.isdir(month_path):
            continue

        for file in os.listdir(month_path):
            if 'stop-and-search' not in file:
                continue

            file_path = os.path.join(month_path, file)

            try:
                df = pd.read_csv(file_path)

                # แยกชื่อเมืองจากชื่อไฟล์ เช่น avon-and-somerset
                city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1].strip()
                df['เมือง'] = city
                all_data.append(df)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

    return pd.concat(all_data, ignore_index=True)
# Out:
# Mounted at /content/drive

# %%
# 1. โหลดข้อมูล
path = "/content/drive/MyDrive/Python&DataViz2025/data"
df = read_all_data(path)

# 2. กรองเฉพาะคน Asian ใช้คอลัมม์ Officer-defined ethnicity เพราะคอลัมม์ Self-defined ethnicity บาง row ไม่มีคำว่า Asian
df = df[df["Officer-defined ethnicity"].str.contains("Asian", case=False, na=False)]

# 3. แปลงวัน และเพิ่มคอลัมน์เดือน
df["Date"] = pd.to_datetime(df["Date"], errors="coerce").dt.tz_localize(None)
df["Month"] = df["Date"].dt.to_period("M")

# 4. สรุปจำนวนในแต่ละเดือน
counts = df["Month"].value_counts().sort_index().reset_index()
counts.columns = ["Month", "Asian Count"]

# 5. แสดงเดือนน้อยสุดและมากสุด
print("เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asian น้อยที่สุด:\n",
      counts.nsmallest(1, "Asian Count").iloc[0].to_string())

print("\nเดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asian มากที่สุด:\n",
      counts.nlargest(1, "Asian Count",).iloc[0].to_string())
# Out:
# เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asian น้อยที่สุด:
#  Month          2025-05
# Asian Count       2738
#
# เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asian มากที่สุด:
#  Month          2025-01
# Asian Count       3537

# %%
df.head(3)
# Out:
#              Type                Date Part of a policing operation  \
# 24  Person search 2025-01-04 04:40:00                          NaN
# 73  Person search 2025-01-10 07:16:00                          NaN
# 96  Person search 2025-01-11 19:45:00                          NaN
#
#     Policing operation   Latitude  Longitude Gender Age range  \
# 24                 NaN  53.215049  -4.150063   Male     25-34
# 73                 NaN  53.074874  -2.885333   Male   over 34
# 96                 NaN  52.983303  -3.066491   Male     25-34
#
#                Self-defined ethnicity Officer-defined ethnicity  \
# 24    Other ethnic group - Not stated                     Asian
# 73    Other ethnic group - Not stated                     Asian
# 96  Asian/Asian British - Bangladeshi                     Asian
#
#                                           Legislation  \
# 24  Police and Criminal Evidence Act 1984 (section 1)
# 73  Police and Criminal Evidence Act 1984 (section 1)
# ...

# %%
counts
# Out:
#      Month  Asian Count
# 0  2025-01         3537
# 1  2025-02         3082
# 2  2025-03         2960
# 3  2025-04         3139
# 4  2025-05         2738

# %% [markdown]
# # การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %%
stopandsearch_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3623504028.py in <cell line: 0>()
# ----> 1 stopandsearch_df.head()
#
# NameError: name 'stopandsearch_df' is not defined

# %% [markdown]
# ## ตรวจสอบ missing

# %%
from google.colab import drive
drive.mount('/content/drive')
path_to_stopandsearch = '/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
# Out:
# Mounted at /content/drive

# %%
stopandsearch_df.isnull()
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0    False  False                         False                True     False
# 1    False  False                         False                True     False
# 2    False  False                         False                True     False
# 3    False  False                         False                True     False
# 4    False  False                         False                True     False
# ..     ...    ...                           ...                 ...       ...
# 382  False  False                         False                True     False
# 383  False  False                         False                True     False
# 384  False  False                         False                True     False
# 385  False  False                         False                True     False
# 386  False  False                         False                True     False
#
# ...

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# # ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
stopandsearch_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# ## Drop แบบ เลือกพิจารณาเฉพาะบาง column

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'])
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'],inplace=True)

# %%
stopandsearch_df.shape
# Out:
# (356, 15)

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ## เลือกเฉพาะ Column ที่เราสนใจก่อน ค่อย Drop

# %%
stopandsearch_df[['Outcome','Type','Age range']]
# Out:
#                           Outcome                       Type Age range
# 0                          Arrest              Person search     25-34
# 1    A no further action disposal              Person search     10-17
# 2    A no further action disposal              Person search     10-17
# 3    A no further action disposal              Person search     10-17
# 4    A no further action disposal              Person search     10-17
# ..                            ...                        ...       ...
# 382  A no further action disposal              Person search   over 34
# 383  A no further action disposal              Person search     25-34
# 384          Community resolution              Person search   over 34
# 385  A no further action disposal              Person search     18-24
# 386  A no further action disposal  Person and Vehicle search     18-24
#
# [356 rows x 3 columns]

# %%
stopandsearch_df[['Outcome','Type','Age range']].dropna()
# Out:
#                           Outcome                       Type Age range
# 0                          Arrest              Person search     25-34
# 1    A no further action disposal              Person search     10-17
# 2    A no further action disposal              Person search     10-17
# 3    A no further action disposal              Person search     10-17
# 4    A no further action disposal              Person search     10-17
# ..                            ...                        ...       ...
# 382  A no further action disposal              Person search   over 34
# 383  A no further action disposal              Person search     25-34
# 384          Community resolution              Person search   over 34
# 385  A no further action disposal              Person search     18-24
# 386  A no further action disposal  Person and Vehicle search     18-24
#
# [340 rows x 3 columns]

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %% [markdown]
# ### เติม dummy

# %%
stopandsearch_df.fillna('Unknown')
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation Policing operation   Latitude Longitude  \
# 0                           False            Unknown  51.881481  -0.41311
# 1                           False            Unknown  52.132059   -0.2966
# ...

# %%
stopandsearch_df.fillna('Unknown').isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                          False
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.fillna({'Gender':'Unknown'})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.fillna({'Gender':'Unknown'}).isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.fillna({'Gender':'Unknown'},inplace=True)

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
stopandsearch_df.duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Length: 356, dtype: bool

# %% [markdown]
# ### เรียกดู แถวที่ซ้ำ

# %%
stopandsearch_df[stopandsearch_df.duplicated()]
# Out:
#               Type                       Date  Part of a policing operation  \
# 2    Person search  2025-01-01T02:30:00+00:00                         False
# 4    Person search  2025-01-01T02:30:00+00:00                         False
# 43   Person search  2025-01-05T03:25:00+00:00                         False
# 86   Person search  2025-01-08T02:06:00+00:00                         False
# 87   Person search  2025-01-08T02:06:00+00:00                         False
# 88   Person search  2025-01-08T02:06:00+00:00                         False
# 231  Person search  2025-01-19T18:45:00+00:00                         False
# 243  Person search  2025-01-20T15:55:00+00:00                         False
# 244  Person search  2025-01-20T15:55:00+00:00                         False
# 245  Person search  2025-01-20T15:55:00+00:00                         False
# 308  Person search  2025-01-27T12:15:00+00:00                          True
#
# ...

# %%
stopandsearch_df.duplicated()==False
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 356, dtype: bool

# %%
~stopandsearch_df.duplicated()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 356, dtype: bool

# %% [markdown]
# ### ลบ Duplicate

# %%
stopandsearch_df[~stopandsearch_df.duplicated()]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ### เติมค่าว่างด้วยค่ากลาง

# %%
stopandsearch_df['Latitude'].mean()
# Out:
# np.float64(51.96157266326531)

# %%
stopandsearch_df.fillna({'Latitude':stopandsearch_df['Latitude'].mean(), # แทนค่า Lat ด้วย mean
                         'Longitude':stopandsearch_df['Longitude'].mean(), # แทนค่า Long ด้วย mean
                         'Age range':stopandsearch_df['Age range'].mode()},
                         inplace=True) # แทนค่า Age rang ด้วย mode

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# # Quiz 9 หาดูว่า Row ไหนบ้างที่ยังมี missing ใน Column ```Age Range``` อยู่

# %%
# หาบรรทัดที่ Age range เป็น missing
missing_age = stopandsearch_df[stopandsearch_df['Age range'].isnull()]

# แสดงผล
missing_age
# Out:
#               Type                       Date  Part of a policing operation  \
# 52   Person search  2025-01-06T08:00:00+00:00                         False
# 77   Person search  2025-01-07T15:10:00+00:00                          True
# 83   Person search  2025-01-07T22:31:00+00:00                         False
# 228  Person search  2025-01-19T18:45:00+00:00                         False
# 231  Person search  2025-01-19T18:45:00+00:00                         False
# 242  Person search  2025-01-20T15:55:00+00:00                         False
# 243  Person search  2025-01-20T15:55:00+00:00                         False
# 244  Person search  2025-01-20T15:55:00+00:00                         False
# 245  Person search  2025-01-20T15:55:00+00:00                         False
# 282  Person search  2025-01-25T15:40:00+00:00                         False
# 296  Person search  2025-01-26T18:40:00+00:00                         False
# ...

# %%
stopandsearch_df['Age range'].mode().iloc[0]
# Out:
# 'over 34'

# %%
stopandsearch_df.fillna({'Age range':stopandsearch_df['Age range'].mode().iloc},
                         inplace=True) # แทนค่า Age rang ด้วย mode

# %%
stopandsearch_df[stopandsearch_df['Age range'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = stopandsearch_df.iloc[:10,:]

# %%
this_data
# Out:
#              Type                       Date  Part of a policing operation  \
# 0   Person search  2025-01-01T00:35:00+00:00                         False
# 1   Person search  2025-01-01T02:30:00+00:00                         False
# 2   Person search  2025-01-01T02:30:00+00:00                         False
# 3   Person search  2025-01-01T02:30:00+00:00                         False
# 4   Person search  2025-01-01T02:30:00+00:00                         False
# 5   Person search  2025-01-01T10:00:00+00:00                         False
# 7   Person search  2025-01-01T12:12:00+00:00                         False
# 8   Person search  2025-01-01T14:35:00+00:00                          True
# 9   Person search  2025-01-01T15:10:00+00:00                          True
# 10  Person search  2025-01-01T15:10:00+00:00                          True
#
#     Policing operation   Latitude  Longitude  Gender Age range  \
# 0                  NaN  51.881481  -0.413110    Male     25-34
# ...

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, Type                                                                            Person search
# Date                                                                2025-01-01T00:35:00+00:00
# Part of a policing operation                                                            False
# Policing operation                                                                        NaN
# Latitude                                                                            51.881481
# Longitude                                                                            -0.41311
# Gender                                                                                   Male
# Age range                                                                               25-34
# Self-defined ethnicity                      Mixed/Multiple ethnic groups - Any other Mixed...
# Officer-defined ethnicity                                                               Other
# ...

# %%
each_row
# Out:
# (10,
#  Type                                                                Person search
#  Date                                                    2025-01-01T15:10:00+00:00
#  Part of a policing operation                                                 True
#  Policing operation                                                            NaN
#  Latitude                                                                      NaN
#  Longitude                                                                     NaN
#  Gender                                                                       Male
#  Age range                                                                 over 34
#  Self-defined ethnicity                            Other ethnic group - Not stated
#  Officer-defined ethnicity                                                   Asian
#  Legislation                                 Misuse of Drugs Act 1971 (section 23)
# ...

# %%
each_row[1]
# Out:
# Type                                                                Person search
# Date                                                    2025-01-01T15:10:00+00:00
# Part of a policing operation                                                 True
# Policing operation                                                            NaN
# Latitude                                                                      NaN
# Longitude                                                                     NaN
# Gender                                                                       Male
# Age range                                                                 over 34
# Self-defined ethnicity                            Other ethnic group - Not stated
# Officer-defined ethnicity                                                   Asian
# Legislation                                 Misuse of Drugs Act 1971 (section 23)
# ...

# %%
each_row[1]['Date']
# Out:
# '2025-01-01T15:10:00+00:00'

# %%
for each_row in this_data.iterrows():
    print(each_row[1]['Date'],
          each_row[1]['Self-defined ethnicity'],
          each_row[1]['Legislation'],
          end='\n*************************\n')
# Out:
# 2025-01-01T00:35:00+00:00 Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T02:30:00+00:00 White - English/Welsh/Scottish/Northern Irish/British Police and Criminal Evidence Act 1984 (section 1)
# *************************
# 2025-01-01T10:00:00+00:00 Other ethnic group - Not stated Misuse of Drugs Act 1971 (section 23)
# *************************
# ...

# %% [markdown]
# # สร้างตารางใหม่

# %% [markdown]
# ![pandas-dataframe-shadow-2.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
# Dictionary บนซ้าย
sales = [
        {'account': 'Jones LLC', 'Jan': 150, 'Feb': 200, 'Mar': 140},
        {'account': 'Alpha Co', 'Jan': 200, 'Feb': 210, 'Mar': 215},
        {'account': 'Blue Inc', 'Jan': 50, 'Feb': 90, 'Mar': 95}
        ]
df = pd.DataFrame(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
# Dictionary ล่างซ้าย
sales = {
        'account': ['Jones LLC', 'Alpha Co', 'Blue Inc'],
        'Jan': [150, 200, 50],
        'Feb': [200, 210, 90],
        'Mar': [140, 215, 95]
        }
df = pd.DataFrame.from_dict(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
# List บนขวา
sales = [
        ('Jones LLC', 150, 200, 140),
        ('Alpha Co', 200, 210, 215),
        ('Blue Inc', 50, 90, 95)
        ]
labels =['account', 'Jan', 'Feb', 'Mar']
df = pd.DataFrame.from_records(sales, columns=labels)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
# List ล่างขวา อันที่ผิด
sales = [
        ('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
        ('Jan', [150, 200, 50]),
        ('Feb', [200, 210, 90]),
        ('Mar', [140, 215, 95])
        ]
df = pd.DataFrame.from_items(sales) # from_items ถูกถอดออก
df

# %%
# List ล่างขวา แก้ไข code
sales = [
        ('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
        ('Jan', [150, 200, 50]),
        ('Feb', [200, 210, 90]),
        ('Mar', [140, 215, 95])
        ]
df = pd.DataFrame(dict(sales))
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
Police = [
            {'วันที่':'01-09-2568','ชื่อ':'รุ่งแสง','รหัส':'292','ความผิด':'ไม่ใส่หมวกกันน็อค'},
            {'วันที่':'02-09-2568','ชื่อ':'พรพรรณ','รหัส':'377','ความผิด':'ผ่าไฟแดง'},
            {'วันที่':'03-09-2568','ชื่อ':'วรพล','รหัส':'385','ความผิด':'ขโมยมอเตอร์ไซต์'},
        ]

# %%
kku_police = pd.DataFrame(Police)
kku_police
# Out:
#        วันที่     ชื่อ รหัส            ความผิด
# 0  01-09-2568  รุ่งแสง  292  ไม่ใส่หมวกกันน็อค
# 1  02-09-2568   พรพรรณ  377           ผ่าไฟแดง
# 2  03-09-2568     วรพล  385    ขโมยมอเตอร์ไซต์

# %% [markdown]
# # Save ตาราง

# %%
kku_police.to_csv('ตำรวจ_มข.csv')

# %%
kku_police.to_excel('ตำรวจ_มข.xlsx',sheet_name='ความผิด')

# %% [markdown]
# # ต่อตาราง

# %% [markdown]
# ## แกน X (เพิ่ม Column -> เพิ่มรายละเอียดข้อมูล)

# %%
outcomes = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-avon-and-somerset-outcomes.csv')

# %%
street = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-avon-and-somerset-street.csv')

# %%
outcomes.head(2)
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                  Location  LSOA code            LSOA name  \
# 0  51.387847  On or near Downside Road  E01014854  North Somerset 013D
# 1        NaN               No location        NaN                  NaN
#
#                                         Outcome type
# 0                        Unable to prosecute suspect
# 1  Further investigation is not in the public int...

# %%
street.head(2)
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# 1  51.411782  On or near Westfield Close  E01014399
#
#                            LSOA name                    Crime type  \
# 0                     Bassetlaw 014F  Violence and sexual offences
# 1  Bath and North East Somerset 001A     Criminal damage and arson
#
#                         Last outcome category  Context
# 0  Action to be taken by another organisation      NaN
# 1                         Under investigation      NaN

# %% [markdown]
# ### ต่อแบบเลือกมาเฉพาะบาง Column (map())

# %%
street['Crime ID'].map(outcomes.set_index('Crime ID')['Outcome type'])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipython-input-2119993980.py in <cell line: 0>()
# ----> 1 street['Crime ID'].map(outcomes.set_index('Crime ID')['Outcome type'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4698         dtype: object
#    4699         """
# -> 4700         new_values = self._map_values(arg, na_action=na_action)
#    4701         return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702             self, method="map"
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# ...

# %% [markdown]
# ### จะเกิด error เมื่อ ตารางที่จะไปเอา data มามี id ที่ duplicated

# %% [markdown]
# #### เราจะแก้

# %%
outcomes[outcomes.duplicated()].head(2)
# Out:
#                                               Crime ID    Month  \
# 102  80f2b0b2e7c1ac8e02b16d24e7b0c7b0ac94d61b5796aa...  2025-01
# 103  80f2b0b2e7c1ac8e02b16d24e7b0c7b0ac94d61b5796aa...  2025-01
#
#                         Reported by                    Falls within  \
# 102  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 103  Avon and Somerset Constabulary  Avon and Somerset Constabulary
#
#      Longitude   Latitude                Location  LSOA code     LSOA name  \
# 102  -2.597964  51.439186  On or near Malago Road  E01033361  Bristol 039F
# 103  -2.597964  51.439186  On or near Malago Road  E01033361  Bristol 039F
#
#                     Outcome type
# 102  Unable to prosecute suspect
# 103  Unable to prosecute suspect

# %%
outcomes_dedup = outcomes.drop_duplicates(keep='last',subset=['Crime ID'])
outcomes_dedup.head(2)
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                  Location  LSOA code            LSOA name  \
# 0  51.387847  On or near Downside Road  E01014854  North Somerset 013D
# 1        NaN               No location        NaN                  NaN
#
#                                         Outcome type
# 0                        Unable to prosecute suspect
# 1  Further investigation is not in the public int...

# %% [markdown]
# ได้ column ที่ map เสร็จแล้ว

# %%
street['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3        Unable to prosecute suspect
# 4        Unable to prosecute suspect
#                     ...
# 14823                            NaN
# 14824                            NaN
# 14825                            NaN
# 14826                            NaN
# 14827    Unable to prosecute suspect
# Name: Crime ID, Length: 14828, dtype: object

# %% [markdown]
# ## เพิ่ม column ใหม่ในตาราง

# %%
street['Outcome type'] = street['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
street.head()
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
# 2  cf50d7824b02ca548125204807e34491d14de60b1812e7...  2025-01
# 3  63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4  7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# ...

# %%
street[street['Outcome type'] == 'Unable to prosecute suspect'].head(2)
# Out:
#                                             Crime ID    Month  \
# 3  63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4  7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
#
#     Latitude                    Location  LSOA code  \
# 3  51.416147  On or near St Francis Road  E01014399
# 4  51.416147  On or near St Francis Road  E01014399
#
#                            LSOA name                    Crime type  \
# 3  Bath and North East Somerset 001A  Violence and sexual offences
# 4  Bath and North East Somerset 001A  Violence and sexual offences
#
#          Last outcome category  Context                 Outcome type
# 3  Unable to prosecute suspect      NaN  Unable to prosecute suspect
# ...

# %% [markdown]
# ## แกน Y (เพิ่ม Rows -> เพิ่มจำนวนข้อมูล)

# %%
outcomes.shape
# Out:
# (8666, 10)

# %%
outcomes.head()
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
# 2  ae2635027b0484e1ef028b833ba5a795a3f33104ac9c82...  2025-01
# 3  d4250554f997530722b58740c8679665f3327de2e5b601...  2025-01
# 4  5fcb9a243ac6f29f7ef5bcf6d316d8936897ea315220ec...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.576637
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                     Location  LSOA code            LSOA name  \
# ...

# %%
Loutcomes1 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-city-of-london-outcomes.csv')
Loutcomes2 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-02/2025-02-city-of-london-outcomes.csv')
Loutcomes3 = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-03/2025-03-city-of-london-outcomes.csv')

# %% [markdown]
# ### ต่อตารางแกน Y (map())

# %%
Loutcomes_123 = pd.concat([Loutcomes1,Loutcomes2,Loutcomes3])
# Out:
# (2017, 10)

# %% [markdown]
# # group by

# %% [markdown]
# ![GROUPBY.png](data:image/png;base64,...)

# %%
stopNsearch = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/data/2025-01/2025-01-city-of-london-stop-and-search.csv')
stopNsearch.head()
# Out:
#                         Type                       Date  \
# 0  Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1  Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2  Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3  Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4              Person search  2025-01-02T03:19:44+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN        NaN        NaN
# 1                           NaN                 NaN        NaN        NaN
# 2                           NaN                 NaN        NaN        NaN
# 3                           NaN                 NaN        NaN        NaN
# 4                           NaN                 NaN  51.510042  -0.120439
#
#   Gender Age range                           Self-defined ethnicity  \
# 0   Male     18-24                Asian/Asian British - Bangladeshi
# ...

# %% [markdown]
# เดือนมกราคม มี case ที่ถูกเรียกค้น โดยผู้ต้องสงสัยเป็นเชื้อชาติต่างๆ อย่างละกี่ case

# %%
stopNsearch.groupby('Self-defined ethnicity').count().head()
# Out:
#                                                   Type  Date  \
# Self-defined ethnicity
# Asian/Asian British - Any other Asian background     5     5
# Asian/Asian British - Bangladeshi                    6     6
# Asian/Asian British - Indian                         1     1
# Asian/Asian British - Pakistani                      6     6
# Black/African/Caribbean/Black British - African     11    11
#
#                                                   Part of a policing operation  \
# Self-defined ethnicity
# Asian/Asian British - Any other Asian background                             0
# Asian/Asian British - Bangladeshi                                            0
# Asian/Asian British - Indian                                                 0
# Asian/Asian British - Pakistani                                              0
# Black/African/Caribbean/Black British - African                              0
#
#                                                   Policing operation  \
# ...

# %%
stopNsearch.groupby('Self-defined ethnicity').count().reset_index().head()
# Out:
#                              Self-defined ethnicity  Type  Date  \
# 0  Asian/Asian British - Any other Asian background     5     5
# 1                 Asian/Asian British - Bangladeshi     6     6
# 2                      Asian/Asian British - Indian     1     1
# 3                   Asian/Asian British - Pakistani     6     6
# 4   Black/African/Caribbean/Black British - African    11    11
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                             0                   0         4          4
# 1                             0                   0         4          4
# 2                             0                   0         1          1
# 3                             0                   0         3          3
# 4                             0                   0         9          9
#
#    Gender  Age range  Officer-defined ethnicity  Legislation  \
# 0       5          5                          5            5
# ...

# %%
stopNsearch.groupby(['Self-defined ethnicity', 'Officer-defined ethnicity']).count().reset_index().head()
# Out:
#                              Self-defined ethnicity Officer-defined ethnicity  \
# 0  Asian/Asian British - Any other Asian background                     Asian
# 1  Asian/Asian British - Any other Asian background                     Other
# 2                 Asian/Asian British - Bangladeshi                     Asian
# 3                 Asian/Asian British - Bangladeshi                     White
# 4                      Asian/Asian British - Indian                     Asian
#
#    Type  Date  Part of a policing operation  Policing operation  Latitude  \
# 0     4     4                             0                   0         3
# 1     1     1                             0                   0         1
# 2     5     5                             0                   0         4
# 3     1     1                             0                   0         0
# 4     1     1                             0                   0         1
#
# ...

# %%
stopNsearch.groupby(['Officer-defined ethnicity','Self-defined ethnicity']).count().reset_index().head()
# Out:
#   Officer-defined ethnicity  \
# 0                     Asian
# 1                     Asian
# 2                     Asian
# 3                     Asian
# 4                     Asian
#
#                               Self-defined ethnicity  Type  Date  \
# 0   Asian/Asian British - Any other Asian background     4     4
# 1                  Asian/Asian British - Bangladeshi     5     5
# 2                       Asian/Asian British - Indian     1     1
# 3                    Asian/Asian British - Pakistani     6     6
# 4  Mixed/Multiple ethnic groups - Any other Mixed...     2     2
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                             0                   0         3          3
# 1                             0                   0         4          4
# 2                             0                   0         1          1
# 3                             0                   0         3          3
# ...
